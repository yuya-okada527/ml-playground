# %%
similar_movies = context.catalog.load("similar_movies")
similar_movies.head()
# Out:
# 2021-02-20 22:03:14,347 - kedro.io.data_catalog - INFO - Loading data from `similar_movies` (CSVDataSet)...
#    movie_id                         similar_movie_ids
# 0       671      [674, 24428, 464052, 141052, 293167]
# 1       674     [671, 464052, 545609, 141052, 293167]
# 2     24428  [141052, 299537, 299536, 495764, 299534]
# 3     38700  [290859, 474350, 299537, 384018, 454626]
# 4     99861  [299534, 333339, 299537, 383498, 290859]

# %%
for row in similar_movies.itertuples():
    print(row.movie_id, row.similar_movie_ids)
# Out:
# 671 [674, 24428, 464052, 141052, 293167]
# 674 [671, 464052, 545609, 141052, 293167]
# 24428 [141052, 299537, 299536, 495764, 299534]
# 38700 [290859, 474350, 299537, 384018, 454626]
# 99861 [299534, 333339, 299537, 383498, 290859]
# 124905 [373571, 293167, 458156, 337339, 351286]
# 141052 [475557, 24428, 287947, 429617, 495764]
# 181812 [320288, 290859, 99861, 346910, 577922]
# 198663 [99861, 299534, 383498, 299537, 333339]
# 214756 [474350, 338762, 464052, 290859, 475557]
# 274855 [464052, 287947, 475557, 577922, 545609]
# 284053 [299537, 333339, 429617, 24428, 315635]
# 284054 [293167, 495764, 474350, 299536, 475557]
# 287947 [464052, 475557, 474350, 545609, 141052]
# 290859 [474350, 338762, 299537, 320288, 453405]
# 293167 [284054, 373571, 464052, 399579, 337339]
# 299534 [320288, 99861, 299537, 384018, 429617]
# 299536 [24428, 284054, 320288, 399579, 495764]
# 299537 [429617, 290859, 320288, 495764, 384018]
# 315635 [429617, 299537, 495764, 284054, 320288]
# ...
